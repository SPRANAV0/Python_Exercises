# %%
x=10 #1
name="Pranav" #2
pi=3.14 #3
a=5 #4 
b=10 #4
age=20 #5
true=True #6
city="Chennai" #7
negative=-50 #8
zero=0 #9
my_float=1.0 #10
salary=1000 #11
color="Red" #12
l_num=10000000 #13
temperature=37.5 #14
false=False #15
a=1 #16
b=2 #16
c=3 #16
a,b,c=11,12,13 #17
a,b,c=1,1,1 #18
variable="variable" #19
variable="new variable" #20
print(variable) #20
# Out:
# new variable

# %%
x=5 #21 
x=10 #21
y=10 #22
y=y*2 #22
z=10 #23
z=z+1 #23
z=z-2 #24
z=z*5 #25
z= z/2 #26
sum=x+y #27
sub=x-y #28
mul=x*y #29
dev=x/y #30
remainder=x%y #31
x,y=y,x #32
z=x #33
str1="Pranav" #34
str1="Praveen" #34
age=20 #35
age=age+5 #35
marks=90 #36
bonus=10 #36
marks=marks+bonus #36
price=1000 #37
discount=(20/100)*price #37
price=price-discount #37
number1=10 #38
number1=number1**2 #38
number2=20 #39
number2=number2**3 #39
integer=10 #40
integer=float(integer) #40

# %%
first_name = "Pranav"#41
last_name = "Sivaraj"#42
full_name=first_name+last_name#43
greetings="Good afternoon I'm Pranav "#44
one="one"#45
ball="ball"#45
print(one+ball)#45
string="String"#46
string="String"#46
string="String"#46
sentence="Gravity is not a fource its just a acceleration happening due to the creation of curvature in space-time geomentary by earth."#47
lenth_of_string=len(string)#48
string.upper()#49
string.lower()#50
seven="7"#51
seven+ball#52
multi_line_string="""
This is a multiline string variable where a
single variable contains string values in multiple lines 
or more than one single line.

""" #53
empty_string=""#54
seven + " " + ball#55
single_char="s"#56
special_chars="!@#$%^&*()"#57
quate_string="I can't do this"#58
file="smaple.txt"#59
password="1234567890"#60
# Out:
# oneball

# %%
num1=11#61
num2=12#61
sum=num1+num2#61
average=(num1+num2)/2#62
length=20#63
breadth=25#63
area=length*breadth#63
radius=15#64
circle_area=2*(22/7)*radius#64
principal=10000#65
rate=2#65
time=4#65
simple_interest=principal*(2/100)*4#65
celsius=28#66
fahrenheit=(celsius*9/5)+32#66
fahrenheit=45#67
celsius=(5/9*fahrenheit)-32#67
hours=10#68
minitues=hours*60#68
minitues=120#69
seconds=minitues*60#69
kilometers=20#70
meters=kilometers*1000#70
weight_kg=38#71
weight_g=weight_kg*1000#71
number=35678#72
half=number/2#72
double=number*2#73
square_root=number**2#74
num1=38#75
num2=47#75
large=max(num1,num2)#75
small=min(num1,num2)#76
absolute_value=abs(number)#77
base=178#78
height=287#78
triangle_area=(base*height)*0.5#78
num1,num2,num3=1,2,3#79
sum=num1+num2+num3#79
average=sum/3#80

# %%
student_name,marks="Pranav",90#81
product_name,price="Fan",2900#82
bank_balance,withdraw=299,100#83
username,password="Pranav",123456789#84
car_name,model="BMW",2020#85
book_name,author="Agni Siragugal","Dr.APJ Abdul Kalam"#86
movie_name,rating="Parasakthi",7.9#87
laptop_brand,price="Apple",257000#88
mobile_brand,storage="Oppo","128GB"#89
Country_name,capital="India","New Delhi"#90
num1,num2=19,29#91
num1,num2=num2,num1#91
pi=22/7#92
circumference=2*pi*radius
birth_year=2005
current_age=

# %%
print(3/2)
print(3//2)
x=286451
print(x**0.5)
print(534*534)
print(x-285156)
print(535*535)
print(536*536)
print(286896**0.5)
# Out:
# 1.5
# 1
# 535.2111732764928
# 285156
# 1295
# 286225
# 287296
# 535.6267357031387

# %%
new_string=""
for i in string:
  new_string+=i
print(new_string)
# Out:
# String
